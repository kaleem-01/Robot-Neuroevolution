# %%
from ea_test import main

# %%
main("flat", save=True)
# Out:
# [Gen 01] Best fitness: 0.2410 | X+ 0.241  | energy 0.675  | speed 0.009  | f=1.01Hz
# Elites' fitnesses: [0.24100180716827502, 0.2121210266298247, 0.18983892012232423, 0.15146147227521112, 0.1447140482564971, 0.1366762130922317, 0.12248087230780548, 0.1200681782629632, 0.1143133546067322, 0.11401329357303244]
# [Gen 02] Best fitness: 0.3494 | X+ 0.349  | energy 0.674  | speed 0.009  | f=1.01Hz
# Elites' fitnesses: [0.3493989884996659, 0.3476162550364943, 0.31586291118335064, 0.1995511364408119, 0.19225899896710602, 0.18983892012232423, 0.18267250370038496, 0.17896909577250947, 0.16562082547822915, 0.16333392515270845]
# [Gen 03] Best fitness: 0.4121 | X+ 0.412  | energy 0.479  | speed 0.006  | f=1.03Hz
# Elites' fitnesses: [0.41214453011413693, 0.3493989884996659, 0.3171172040015186, 0.2673117686691143, 0.26291326967575745, 0.24718467614598028, 0.22123745078558177, 0.2063906690270008, 0.19715140131985995, 0.19696806920977833]
# ...
